# %% [markdown]
# # Exploratory Data Analysis
# This notebook contains basic EDA steps for the House Price Prediction dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../housing.csv')
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.hist(bins=50, figsize=(20,15))
plt.show()
