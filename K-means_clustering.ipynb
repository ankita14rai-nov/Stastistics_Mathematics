# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data= {
    "height":[185, 170, 168, 179, 182, 188, 180, 183, 180, 180, 177],
    "weight": [72, 56,60, 68, 72, 77, 70, 84, 88, 67, 76]
}

df= pd.DataFrame(data)
print(df)
# Out:
#     height  weight
# 0      185      72
# 1      170      56
# 2      168      60
# 3      179      68
# 4      182      72
# 5      188      77
# 6      180      70
# 7      183      84
# 8      180      88
# 9      180      67
# 10     177      76
